# %%
import tensorflow as tf
tf.set_random_seed(777)

#선형 회귀
x_train = [1,2,3]
y_train = [1,2,3]
W = tf.Variable(tf.random_normal([1]), name = 'weight') #가중치에 우선 랜덤수를 집어넣음
b = tf.Variable(tf.random_normal([1]), name = 'bias') #모수 랜덤
#우리의 모델
hypo = x_train*w + b

# %%
#cost function
cost = tf.reduce_mean(tf.square(hypo - y_train))

# %%
#gradientDescent
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())#그래프의 글로벌 변수 초기화(반드시 실행)

# %%
for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(w), sess.run(b))
# Out:
# 0 2.823292 [2.1286771] [-0.8523567]
# 20 0.19035067 [1.533928] [-1.0505961]
# 40 0.15135698 [1.4572546] [-1.0239124]
# 60 0.1372696 [1.4308538] [-0.9779527]
# 80 0.12466871 [1.4101374] [-0.93219817]
# 100 0.113226034 [1.3908179] [-0.8884077]
# 120 0.10283363 [1.3724468] [-0.8466577]
# 140 0.09339521 [1.3549428] [-0.80686814]
# 160 0.084823035 [1.3382617] [-0.7689483]
# 180 0.07703761 [1.3223647] [-0.73281056]
# 200 0.06996683 [1.3072149] [-0.6983712]
# 220 0.06354501 [1.2927768] [-0.6655505]
# 240 0.057712615 [1.2790174] [-0.63427216]
# 260 0.0524155 [1.2659047] [-0.6044637]
# 280 0.04760464 [1.2534081] [-0.57605624]
# 300 0.043235257 [1.2414987] [-0.5489836]
# 320 0.039266944 [1.2301493] [-0.5231833]
# 340 0.03566285 [1.2193329] [-0.49859545]
# 360 0.032389563 [1.2090251] [-0.47516325]
# 380 0.029416703 [1.1992016] [-0.45283225]
# 400 0.026716745 [1.18984] [-0.4315508]
# 420 0.024264557 [1.1809182] [-0.41126958]
# 440 0.022037461 [1.1724157] [-0.39194146]
# ...

# %%
#placeholder를 이용한 Linear regression
import tensorflow as tf
tf.set_random_seed(700)

# %%
W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')
X = tf.placeholder(tf.float32, shape = [None]) #그래프에서 특정 값을 지정하는 것이 아니라 session을 실행할때 값을 지정해줌
Y = tf.placeholder(tf.float32, shape = [None])
hypothesis = X*W+b

# %%
#cost function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
#gradientdescent optimizer
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(2001):
    cost_val, W_val, b_val, _ = \
        sess.run([cost, W, b, train],
                feed_dict = {X : [1,2,3], Y : [1,2,3]})
    if step % 20 ==0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 3.6702922e-06 [0.99778026] [0.00504595]
# 20 3.3333201e-06 [0.99788463] [0.00480881]
# 40 3.027185e-06 [0.99798405] [0.0045828]
# 60 2.7494968e-06 [0.9980788] [0.0043674]
# 80 2.4972721e-06 [0.998169] [0.00416217]
# 100 2.2680874e-06 [0.9982551] [0.0039666]
# 120 2.0598209e-06 [0.9983371] [0.00378019]
# 140 1.8707318e-06 [0.99841523] [0.00360254]
# 160 1.6990042e-06 [0.9984897] [0.00343324]
# 180 1.5431442e-06 [0.99856067] [0.00327188]
# 200 1.4015295e-06 [0.9986283] [0.00311813]
# 220 1.2729146e-06 [0.9986928] [0.00297159]
# 240 1.1559858e-06 [0.9987542] [0.00283195]
# 260 1.0499976e-06 [0.99881274] [0.00269886]
# 280 9.5357404e-07 [0.9988685] [0.00257204]
# 300 8.660533e-07 [0.99892175] [0.00245118]
# 320 7.86625e-07 [0.9989724] [0.002336]
# 340 7.143606e-07 [0.9990207] [0.00222622]
# 360 6.4893976e-07 [0.99906665] [0.00212164]
# 380 5.8932454e-07 [0.99911046] [0.00202196]
# 400 5.351937e-07 [0.9991523] [0.00192696]
# 420 4.8617125e-07 [0.9991921] [0.00183644]
# ...

# %%
#test model
print(sess.run(hypothesis, feed_dict = {X : [5]}))
print(sess.run(hypothesis, feed_dict = {X : [2.5]}))
print(sess.run(hypothesis, feed_dict = {X : [1.5, 3.5]}))
# Out:
# [4.999951]
# [2.4999962]
# [1.5000144 3.499978 ]

# %%
#다른 모수로 훈련
for step in range(2001):
    cost_val, W_val, b_val, _ = \
        sess.run([cost, W, b, train],
                 feed_dict={X: [1, 2, 3, 4, 5],
                            Y: [2.1, 3.1, 4.1, 5.1, 6.1]})
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 1.210028 [1.0659834] [0.02204183]
# 20 0.1659119 [1.2625597] [0.14828351]
# 40 0.14487396 [1.2462718] [0.2108635]
# 60 0.12651944 [1.2301474] [0.26909488]
# 80 0.11049042 [1.2150749] [0.32351145]
# 100 0.09649209 [1.2009894] [0.3743643]
# 120 0.08426732 [1.1878265] [0.4218867]
# 140 0.0735913 [1.1755257] [0.46629688]
# 160 0.0642678 [1.1640302] [0.5077987]
# 180 0.056125514 [1.1532876] [0.5465826]
# 200 0.04901484 [1.1432488] [0.5828263]
# 220 0.04280498 [1.1338673] [0.6166965]
# 240 0.037381873 [1.1251003] [0.64834857]
# 260 0.03264587 [1.1169072] [0.6779276]
# 280 0.02850991 [1.1092509] [0.7055693]
# 300 0.024897952 [1.1020961] [0.7314008]
# 320 0.02174357 [1.0954098] [0.7555406]
# 340 0.018988801 [1.0891613] [0.77809954]
# 360 0.016583066 [1.083322] [0.7991811]
# 380 0.014482126 [1.0778652] [0.81888187]
# 400 0.012647355 [1.0727657] [0.8372925]
# 420 0.011044994 [1.0680002] [0.8544975]
# 440 0.009645677 [1.0635468] [0.8705758]
# 460 0.0084236385 [1.0593851] [0.885601]
# ...

# %%
print(sess.run(hypothesis, feed_dict={X: [5]}))
print(sess.run(hypothesis, feed_dict={X: [2.5]}))
print(sess.run(hypothesis, feed_dict={X: [1.5, 3.5]}))
# Out:
# [6.1004486]
# [3.5996416]
# [2.5993187 4.599964 ]

# %%
#multivariate linear regression
import tensorflow as tf
tf.set_random_seed(777)  # for reproducibility

x_data = [[73., 80., 75.],
          [93., 88., 93.],
          [89., 91., 90.],
          [96., 98., 100.],
          [73., 66., 70.]]
y_data = [[152.],
          [185.],
          [180.],
          [196.],
          [142.]]

# %%
#graph 생성
# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 3])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %%
#session실행
# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, hy_val, _ = sess.run(
        [cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 10 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)
# Out:
# 0 Cost:  70.09713
# Prediction:
#  [[156.10497]
#  [195.14879]
#  [188.43814]
#  [205.03168]
#  [150.82404]]
# 10 Cost:  3.3463356
# Prediction:
#  [[148.88539]
#  [186.45827]
#  [179.88206]
#  [195.71349]
#  [144.1928 ]]
# 20 Cost:  3.328649
# Prediction:
#  [[148.87047]
#  [186.42726]
#  [179.85829]
#  [195.68677]
#  [144.16656]]
# 30 Cost:  3.3116531
# Prediction:
#  [[148.87733]
#  [186.42245]
#  [179.86037]
#  [195.6882 ]
#  [144.16035]]
# 40 Cost:  3.294744
# Prediction:
#  [[148.88423]
#  [186.41772]
#  [179.86247]
#  [195.68965]
#  [144.15419]]
# 50 Cost:  3.277942
# Prediction:
#  [[148.8911 ]
#  [186.413  ]
#  [179.86458]
#  [195.69113]
#  [144.14806]]
# 60 Cost:  3.2612255
# Prediction:
#  [[148.89796]
#  [186.40831]
#  [179.86668]
#  [195.6926 ]
#  [144.14194]]
# 70 Cost:  3.2445831
# Prediction:
#  [[148.90482]
#  [186.40363]
#  [179.8688 ]
#  [195.69408]
#  [144.13583]]
# 80 Cost:  3.228043
# Prediction:
#  [[148.91164]
#  [186.39894]
#  [179.8709 ]
#  [195.69553]
# ...

# %%
#데이터를 파일에서 가져와서 사용하는 방법
import tensorflow as tf
import numpy as np 
tf.set_random_seed(777)

# %%
xy = np.loadtxt('C:/Users/admin/Desktop/새홀리기/data-01-test-score.csv', delimiter = ',', dtype = np.float32)
x_data = xy[:,0:-1]
y_data = xy[:,[-1]]

print(x_data.shape, x_data, len(x_data))
print(y_data.shape, y_data)
# Out:
# (25, 3) [[ 73.  80.  75.]
#  [ 93.  88.  93.]
#  [ 89.  91.  90.]
#  [ 96.  98. 100.]
#  [ 73.  66.  70.]
#  [ 53.  46.  55.]
#  [ 69.  74.  77.]
#  [ 47.  56.  60.]
#  [ 87.  79.  90.]
#  [ 79.  70.  88.]
#  [ 69.  70.  73.]
#  [ 70.  65.  74.]
#  [ 93.  95.  91.]
#  [ 79.  80.  73.]
#  [ 70.  73.  78.]
#  [ 93.  89.  96.]
#  [ 78.  75.  68.]
#  [ 81.  90.  93.]
#  [ 88.  92.  86.]
#  [ 78.  83.  77.]
#  [ 82.  86.  90.]
#  [ 86.  82.  89.]
#  [ 78.  83.  85.]
#  [ 76.  83.  71.]
#  [ 96.  93.  95.]] 25
# (25, 1) [[152.]
#  [185.]
#  [180.]
#  [196.]
#  [142.]
#  [101.]
#  [149.]
#  [115.]
#  [175.]
#  [164.]
#  [141.]
#  [141.]
#  [184.]
#  [152.]
#  [148.]
#  [192.]
#  [147.]
#  [183.]
#  [177.]
#  [159.]
#  [177.]
#  [175.]
#  [175.]
#  [149.]
#  [192.]]

# %%
# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 3])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, hy_val, _ = sess.run(
        [cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 10 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)

# Ask my score
print("Your score will be ", sess.run(
    hypothesis, feed_dict={X: [[100, 70, 101]]}))

print("Other scores will be ", sess.run(hypothesis,
                                        feed_dict={X: [[60, 70, 110], [90, 100, 80]]}))
# Out:
# 0 Cost:  317743.8
# Prediction:
#  [[-376.8061 ]
#  [-450.9517 ]
#  [-445.39957]
#  [-485.6936 ]
#  [-342.65848]
#  [-252.81718]
#  [-364.6057 ]
#  [-271.9438 ]
#  [-421.4727 ]
#  [-391.21475]
#  [-350.0585 ]
#  [-344.3739 ]
#  [-459.6417 ]
#  [-381.0061 ]
#  [-366.01608]
#  [-458.3146 ]
#  [-361.50107]
#  [-438.64688]
#  [-438.40005]
#  [-392.45856]
#  [-427.28372]
#  [-423.60983]
#  [-407.36307]
#  [-378.6381 ]
#  [-467.5096 ]]
# 10 Cost:  33.145496
# Prediction:
#  [[149.51721 ]
#  [181.64459 ]
#  [177.90515 ]
#  [193.13855 ]
#  [139.7954  ]
#  [102.886055]
#  [143.53163 ]
#  [104.769035]
#  [169.74185 ]
#  [156.40735 ]
#  [139.50067 ]
#  [138.34592 ]
#  [184.31221 ]
#  [154.29988 ]
#  [144.45825 ]
#  [183.62712 ]
#  [148.3016  ]
#  [171.17038 ]
#  [175.51634 ]
#  [156.85092 ]
#  [168.5864  ]
#  [169.85591 ]
#  [160.75008 ]
#  [152.0074  ]
#  [188.09984 ]]
# 20 Cost:  17.903131
# Prediction:
#  [[153.14897 ]
#  [186.01291 ]
#  [182.20709 ]
#  [197.83022 ]
#  [143.12239 ]
# ...

# %%
#queue runner를 이용한 linear regression
import tensorflow as tf
tf.set_random_seed(777)

# %%
filename_queue = tf.train.string_input_producer(
    ['C:/Users/admin/Desktop/새홀리기/data-01-test-score.csv'], shuffle = False, name = 'filename_queue')

reader = tf.TextLineReader()
key, value = reader.read(filename_queue)

# %%
record_defaults = [
    [0.],[0.],[0.],[0.]
] #실수형으로 지정
xy = tf.decode_csv(value, record_defaults = record_defaults)

train_x_batch, train_y_batch = \
    tf.train.batch([xy[0:-1], xy[-1:]], batch_size = 10) #queue에 있는 데이터에서 10개씩 batch에 넣어줌

# %%
# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 3])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

# %%
# Start populating the filename queue.
coord = tf.train.Coordinator()
threads = tf.train.start_queue_runners(sess=sess, coord=coord)

for step in range(2001):
    x_batch, y_batch = sess.run([train_x_batch, train_y_batch])
    cost_val, hy_val, _ = sess.run(
        [cost, hypothesis, train], feed_dict={X: x_batch, Y: y_batch})
    if step % 10 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)

coord.request_stop()
coord.join(threads)

# Ask my score
print("Your score will be ",
      sess.run(hypothesis, feed_dict={X: [[100, 70, 101]]}))

print("Other scores will be ",
      sess.run(hypothesis, feed_dict={X: [[60, 70, 110], [90, 100, 80]]}))
# Out:
# 0 Cost:  57.701935
# Prediction:
#  [[179.5309  ]
#  [178.09631 ]
#  [192.26291 ]
#  [137.89763 ]
#  [ 99.016235]
#  [142.16782 ]
#  [102.96337 ]
#  [165.32483 ]
#  [149.3363  ]
#  [138.07399 ]]
# 10 Cost:  42.44353
# Prediction:
#  [[170.09198]
#  [153.77866]
#  [142.01122]
#  [138.50662]
#  [190.7878 ]
#  [160.89981]
#  [146.44505]
#  [185.95474]
#  [154.62144]
#  [174.85745]]
# 20 Cost:  42.061165
# Prediction:
#  [[170.14238]
#  [153.8536 ]
#  [142.04083]
#  [138.55023]
#  [190.79654]
#  [160.89157]
#  [146.48634]
#  [185.99734]
#  [154.60612]
#  [174.90358]]
# 30 Cost:  41.733612
# Prediction:
#  [[170.16608]
#  [153.90367]
#  [142.04839]
#  [138.57204]
#  [190.77643]
#  [160.85942]
#  [146.50465]
#  [186.01099]
#  [154.56802]
#  [174.92221]]
# 40 Cost:  41.40925
# Prediction:
#  [[170.18947]
#  [153.95337]
#  [142.0558 ]
#  [138.59361]
#  [190.75621]
#  [160.82726]
#  [146.5227 ]
#  [186.02437]
#  [154.52994]
#  [174.94061]]
# 50 Cost:  41.087715
# Prediction:
#  [[170.21274]
# ...
